# %%
import requests, json, sys, time, re
from bs4 import BeautifulSoup
from pprint import pprint

#URL = 'https://twitter.com/i/search/timeline?f=tweets&vertical=default&q=google%20OR%20Google%20OR%20%23google%20OR%20%23Google%20OR%20%24GOOG%20OR%20GOOGLE%20OR%20%23GOOGLE%20lang%3Aen%20since%3A2014-01-01%20until%3A2014-01-30&src=typd&include_available_features=1&include_entities=1&lang=en'

#r = requests. get(URL)
#t = r.text

#f = open('scrape_first_page','w')
#f.write(str(t))
#f.close()

with open ("scrape_first_page", "r") as myfile:
    d=myfile.read().replace('\n', '')

data = json. loads(d)

item_html=data['items_html']

pprint(item_html)

print (len(item_html))

html_string = json. dumps(item_html)
soup = BeautifulSoup(html_string, 'html.parser')

for tweet in soup.findAll('p'):
    print (tweet.text)
    print ('\n')
# Out:
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '      <li class="js-stream-item stream-item stream-item '
# 'expanding-stream-item\n'
# '" data-item-id="428678945718812672" '
# 'id="stream-item-tweet-428678945718812672" data-item-type="tweet">\n'
# '    <ol role="presentation" class="expanded-conversation expansion-container '
# 'js-expansion-container js-navigable-stream">\n'
# '  <li role="presentation" class="original-tweet-container">\n'
# '    \n'
# '\n'
# '\n'
# '  \n'
# '\n'
# '  <div class="tweet original-tweet js-original-tweet js-stream-tweet '
# 'js-actionable-tweet js-profile-popup-actionable  \n'
# '\n'
# '\n'
# '\n'
# ' has-cards\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# 'cards-forward\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '"\n'
# '    \n'
# 'data-tweet-id="428678945718812672"\n'
# '\n'
# 'data-disclosure-type=""\n'
# 'data-item-id="428678945718812672"\n'
# 'data-permalink-path="/wyejon/status/428678945718812672"\n'
# '\n'
# '\n'
# ' data-screen-name="wyejon" data-name="Wye Jon Lee" data-user-id="47516799"\n'
# '\n'
# '\n'
# '\n'
# ' data-has-cards="true"\n'
# '\n'
# 'data-card2-type="summary"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# 'data-expanded-footer="&lt;div class=&quot;js-tweet-details-fixer '
# 'tweet-details-fixer&quot;&gt;&#10;&#10;&#10;&#10;        &lt;div '
# 'class=&quot;entities-media-container js-media-container&quot; '
# 'style=&quot;min-height:0px&quot;&gt;&#10;        &lt;/div&gt;&#10;&#10;  '
# '&lt;div '
# 'class=&quot;js-machine-translated-tweet-container&quot;&gt;&lt;/div&gt;&#10;    '
# '&lt;div class=&quot;js-tweet-stats-container tweet-stats-container '
# '&quot;&gt;&#10;    &lt;/div&gt;&#10;&#10;  &lt;div '
# 'class=&quot;client-and-actions&quot;&gt;&#10;  &lt;span '
# 'class=&quot;metadata&quot;&gt;&#10;    &lt;span&gt;3:59 PM - 29 Jan '
# '2014&lt;/span&gt;&#10;&#10;       &amp;middot; &lt;a '
# 'class=&quot;permalink-link js-permalink js-nav&quot; '
# 'href=&quot;/wyejon/status/428678945718812672&quot;  '
# 'tabindex=&quot;-1&quot;&gt;Details&lt;/a&gt;&#10;    &#10;&#10;&#10;  '
# '&lt;/span&gt;&#10;&lt;/div&gt;&#10;&#10;&#10;&lt;/div&gt;&#10;"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# ' data-component-context="tweet"\n'
# ' data-you-follow="false"\n'
# ' data-follows-you="false"\n'
# ' data-you-block="false"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '>\n'
# '\n'
# '\n'
# '    <div class="context">\n'
# '      \n'
# '      \n'
# '\n'
# '    </div>\n'
# '\n'
# '    <div class="content">\n'
# '\n'
# '      \n'
# '      <div class="stream-item-header">\n'
# '          <a  class="account-group js-account-group js-action-profile '
# 'js-user-profile-link js-nav" href="/wyejon" data-user-id="47516799">\n'
# '    <img class="avatar js-action-profile-avatar" '
# 'src="https://pbs.twimg.com/profile_images/640488034/4284411657_05fc8a8bb3_b_bigger.jpg" '
# 'alt="">\n'
# '    <strong class="fullname js-action-profile-name show-popup-with-id" '
# 'data-aria-label-part>Wye Jon Lee</strong>\n'
# '    <span>&rlm;</span><span class="username js-action-profile-name" '
# 'data-aria-label-part><s>@</s><b>wyejon</b></span>\n'
# '    \n'
# '  </a>\n'
# '\n'
# '        <small class="time">\n'
# '  <a href="/wyejon/status/428678945718812672" class="tweet-timestamp '
# 'js-permalink js-nav js-tooltip" title="3:59 PM - 29 Jan 2014" ><span '
# 'class="_timestamp js-short-timestamp " data-aria-label-part="last" '
# 'data-time="1391039999" data-time-ms="1391039999000" data-long-form="true">29 '
# 'Jan 2014</span></a>\n'
# '</small>\n'
# '\n'
# '          \n'
# '          \n'
# '      </div>\n'
# '\n'
# '\n'
# '      \n'
# '        <p class="TweetTextSize  js-tweet-text tweet-text" lang="en" '
# 'data-aria-label-part="0"><strong>Google</strong> sells Motorola to Lenovo.  '
# 'WTF, I just bought a Moto G! <a href="http://t.co/WTLlHJeCnh" rel="nofollow" '
# 'dir="ltr" data-expanded-url="http://cnet.co/1dP8DAJ" '
# 'class="twitter-timeline-link" target="_blank" title="http://cnet.co/1dP8DAJ" '
# '><span class="tco-ellipsis"></span><span '
# 'class="invisible">http://</span><span '
# 'class="js-display-url">cnet.co/1dP8DAJ</span><span '
# 'class="invisible"></span><span class="tco-ellipsis"><span '
# 'class="invisible">&nbsp;</span></span></a></p>\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '      \n'
# '      \n'
# '            <div class="card2 js-media-container portrait" '
# 'data-card2-name="summary">\n'
# '    \n'
# '    <div class="js-macaw-cards-iframe-container"\n'
# '  '
# 'data-src="/i/cards/tfw/v1/428678945718812672?cardname=summary&amp;earned=true&amp;lang=en"\n'
# '  '
# 'data-autoplay-src="/i/cards/tfw/v1/428678945718812672?cardname=summary&amp;earned=true&amp;lang=en"\n'
# '  data-card-name="summary"\n'
# '  data-card-url="http://t.co/WTLlHJeCnh"\n'
# '  data-publisher-id="30261067"\n'
# '  data-creator-id=""\n'
# '  data-amplify-content-id=""\n'
# '  data-amplify-playlist-url=""\n'
# '  '
# 'data-full-card-iframe-url="/i/cards/tfw/v1/428678945718812672?cardname=summary&amp;earned=true&amp;lang=en"\n'
# '  data-has-autoplayable-media="false">\n'
# '</div>\n'
# '\n'
# '</div>\n'
# '\n'
# '\n'
# '  <div class="expanded-content js-tweet-details-dropdown">\n'
# '    \n'
# '      <div class="js-tweet-details-fixer tweet-details-fixer">\n'
# '\n'
# '\n'
# '\n'
# '        <div class="entities-media-container js-media-container" '
# 'style="min-height:0px">\n'
# '        </div>\n'
# '\n'
# '  <div class="js-machine-translated-tweet-container"></div>\n'
# '    <div class="js-tweet-stats-container tweet-stats-container ">\n'
# '    </div>\n'
# '\n'
# '  <div class="client-and-actions">\n'
# '  <span class="metadata">\n'
# '    <span>3:59 PM - 29 Jan 2014</span>\n'
# '\n'
# '       &middot; <a class="permalink-link js-permalink js-nav" '
# 'href="/wyejon/status/428678945718812672"  tabindex="-1">Details</a>\n'
# '    \n'
# '\n'
# '\n'
# '  </span>\n'
# '</div>\n'
# '\n'
# '\n'
# '</div>\n'
# '\n'
# '  </div>\n'
# '\n'
# '\n'
# '      \n'
# '        \n'
# '<div class="stream-item-footer">\n'
# '    \n'
# '  \n'
# '  \n'
# '      <div class="ProfileTweet-actionCountList u-hiddenVisually">\n'
# '      \n'
# '      <span class="ProfileTweet-action--reply u-hiddenVisually"></span>\n'
# '      <span class="ProfileTweet-action--retweet u-hiddenVisually">\n'
# '        \n'
# '        <span class="ProfileTweet-actionCount"  data-tweet-stat-count="1">\n'
# '          <span class="ProfileTweet-actionCountForAria" '
# 'data-aria-label-part>1 retweet</span>\n'
# '        </span>\n'
# '      </span>\n'
# '      <span class="ProfileTweet-action--favorite u-hiddenVisually">\n'
# '        <span class="ProfileTweet-actionCount"  data-tweet-stat-count="1">\n'
# '          <span class="ProfileTweet-actionCountForAria" '
# 'data-aria-label-part>1 favorite</span>\n'
# '        </span>\n'
# '      </span>\n'
# '    </div>\n'
# '\n'
# '    <div class="ProfileTweet-actionList js-actions " role="group" '
# 'aria-label="Tweet actions">\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--reply">\n'
# '        <button class="ProfileTweet-actionButton u-textUserColorHover '
# 'js-actionButton js-actionReply"\n'
# '          data-modal="ProfileTweet-reply"\n'
# '          type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Reply">\n'
# '            <span class="Icon Icon--reply"></span>\n'
# '            <span class="u-hiddenVisually">Reply</span>\n'
# '          </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--retweet '
# 'js-toggleState js-toggleRt">\n'
# '        <button class="ProfileTweet-actionButton  js-actionButton '
# 'js-actionRetweet"\n'
# '          \n'
# '          data-modal="ProfileTweet-retweet"\n'
# '          type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Retweet">\n'
# '            <span class="Icon Icon--retweet"></span>\n'
# '            <span class="u-hiddenVisually">Retweet</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true">1</span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button><button class="ProfileTweet-actionButtonUndo '
# 'js-actionButton js-actionRetweet" data-modal="ProfileTweet-retweet" '
# 'type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Undo retweet">\n'
# '            <span class="Icon Icon--retweet"></span>\n'
# '            <span class="u-hiddenVisually">Retweeted</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true">1</span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--favorite '
# 'js-toggleState ">\n'
# '        <button class="ProfileTweet-actionButton js-actionButton '
# 'js-actionFavorite" type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Favorite">\n'
# '            <span class="Icon  Icon--favorite"></span>\n'
# '            <span class="u-hiddenVisually">Favorite</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true">1</span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button><button class="ProfileTweet-actionButtonUndo u-linkClean '
# 'js-actionButton js-actionFavorite" type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Undo favorite">\n'
# '            <span class="Icon  Icon--favorite"></span>\n'
# '            <span class="u-hiddenVisually">Favorited</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true">1</span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '\n'
# '      \n'
# '        <div class="ProfileTweet-action ProfileTweet-action--more '
# 'js-more-ProfileTweet-actions">\n'
# '          <div class="dropdown">\n'
# '  <button class="ProfileTweet-actionButton u-textUserColorHover '
# 'dropdown-toggle js-dropdown-toggle" type="button">\n'
# '      <div class="IconContainer js-tooltip" title="More">\n'
# '        <span class="Icon Icon--dots"></span>\n'
# '        <span class="u-hiddenVisually">More</span>\n'
# '      </div>\n'
# '  </button>\n'
# '  <div class="dropdown-menu">\n'
# '  <div class="dropdown-caret">\n'
# '    <div class="caret-outer"></div>\n'
# '    <div class="caret-inner"></div>\n'
# '  </div>\n'
# '  <ul>\n'
# '    \n'
# '      <li class="copy-link-to-tweet js-actionCopyLinkToTweet">\n'
# '        <button type="button" class="dropdown-link">Copy link to '
# 'Tweet</button>\n'
# '      </li>\n'
# '        <li class="embed-link js-actionEmbedTweet" data-nav="embed_tweet">\n'
# '          <button type="button" class="dropdown-link">Embed Tweet</button>\n'
# '        </li>\n'
# '        \n'
# '  </ul>\n'
# '</div>\n'
# '\n'
# '</div>\n'
# '\n'
# '        </div>\n'
# '    </div>\n'
# '\n'
# '</div>\n'
# '\n'
# '\n'
# '\n'
# '      \n'
# '      \n'
# '\n'
# '    </div>\n'
# '  </div>\n'
# '\n'
# '\n'
# '  </li>\n'
# '</ol>\n'
# '\n'
# '</li>\n'
# '\n'
# '      <li class="js-stream-item stream-item stream-item '
# 'expanding-stream-item\n'
# '" data-item-id="428678940157546496" '
# 'id="stream-item-tweet-428678940157546496" data-item-type="tweet">\n'
# '      \n'
# '\n'
# '\n'
# '  \n'
# '\n'
# '  <div class="tweet original-tweet js-original-tweet js-stream-tweet '
# 'js-actionable-tweet js-profile-popup-actionable  \n'
# '\n'
# '\n'
# '\n'
# ' has-cards\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '"\n'
# '    \n'
# 'data-tweet-id="428678940157546496"\n'
# '\n'
# 'data-disclosure-type=""\n'
# 'data-item-id="428678940157546496"\n'
# 'data-permalink-path="/DavidBussin/status/428678940157546496"\n'
# '\n'
# '\n'
# ' data-screen-name="DavidBussin" data-name="DavidBussin" '
# 'data-user-id="15102695"\n'
# '\n'
# '\n'
# '\n'
# ' data-has-cards="true"\n'
# '\n'
# 'data-card2-type="summary"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# 'data-expanded-footer="&lt;div class=&quot;js-tweet-details-fixer '
# 'tweet-details-fixer&quot;&gt;&#10;&#10;            &lt;div class=&quot;card2 '
# 'js-media-container portrait&quot; '
# 'data-card2-name=&quot;summary&quot;&gt;&#10;    &#10;    &lt;div '
# 'class=&quot;js-macaw-cards-iframe-container&quot;&#10;  '
# 'data-src=&quot;/i/cards/tfw/v1/428678940157546496?cardname=summary&amp;amp;earned=true&amp;amp;lang=en&quot;&#10;  '
# 'data-autoplay-src=&quot;/i/cards/tfw/v1/428678940157546496?cardname=summary&amp;amp;earned=true&amp;amp;lang=en&quot;&#10;  '
# 'data-card-name=&quot;summary&quot;&#10;  '
# 'data-card-url=&quot;http://t.co/5VgcLcV1JH&quot;&#10;  '
# 'data-publisher-id=&quot;67358777&quot;&#10;  '
# 'data-creator-id=&quot;&quot;&#10;  '
# 'data-amplify-content-id=&quot;&quot;&#10;  '
# 'data-amplify-playlist-url=&quot;&quot;&#10;  '
# 'data-full-card-iframe-url=&quot;/i/cards/tfw/v1/428678940157546496?cardname=summary&amp;amp;earned=true&amp;amp;lang=en&quot;&#10;  '
# 'data-has-autoplayable-media=&quot;false&quot;&gt;&#10;&lt;/div&gt;&#10;&#10;&lt;/div&gt;&#10;&#10;&#10;&#10;        '
# '&lt;div class=&quot;entities-media-container js-media-container&quot; '
# 'style=&quot;min-height:0px&quot;&gt;&#10;        &lt;/div&gt;&#10;&#10;  '
# '&lt;div '
# 'class=&quot;js-machine-translated-tweet-container&quot;&gt;&lt;/div&gt;&#10;    '
# '&lt;div class=&quot;js-tweet-stats-container tweet-stats-container '
# '&quot;&gt;&#10;    &lt;/div&gt;&#10;&#10;  &lt;div '
# 'class=&quot;client-and-actions&quot;&gt;&#10;  &lt;span '
# 'class=&quot;metadata&quot;&gt;&#10;    &lt;span&gt;3:59 PM - 29 Jan '
# '2014&lt;/span&gt;&#10;&#10;       &amp;middot; &lt;a '
# 'class=&quot;permalink-link js-permalink js-nav&quot; '
# 'href=&quot;/DavidBussin/status/428678940157546496&quot;  '
# 'tabindex=&quot;-1&quot;&gt;Details&lt;/a&gt;&#10;    &#10;&#10;&#10;  '
# '&lt;/span&gt;&#10;&lt;/div&gt;&#10;&#10;&#10;&lt;/div&gt;&#10;"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# ' data-component-context="tweet"\n'
# ' data-you-follow="false"\n'
# ' data-follows-you="false"\n'
# ' data-you-block="false"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '>\n'
# '\n'
# '\n'
# '    <div class="context">\n'
# '      \n'
# '      \n'
# '\n'
# '    </div>\n'
# '\n'
# '    <div class="content">\n'
# '\n'
# '      \n'
# '      <div class="stream-item-header">\n'
# '          <a  class="account-group js-account-group js-action-profile '
# 'js-user-profile-link js-nav" href="/DavidBussin" data-user-id="15102695">\n'
# '    <img class="avatar js-action-profile-avatar" '
# 'src="https://pbs.twimg.com/profile_images/630473302625132545/60egqJ5m_bigger.jpg" '
# 'alt="">\n'
# '    <strong class="fullname js-action-profile-name show-popup-with-id" '
# 'data-aria-label-part>DavidBussin</strong>\n'
# '    <span>&rlm;</span><span class="username js-action-profile-name" '
# 'data-aria-label-part><s>@</s><b>DavidBussin</b></span>\n'
# '    \n'
# '  </a>\n'
# '\n'
# '        <small class="time">\n'
# '  <a href="/DavidBussin/status/428678940157546496" class="tweet-timestamp '
# 'js-permalink js-nav js-tooltip" title="3:59 PM - 29 Jan 2014" ><span '
# 'class="_timestamp js-short-timestamp " data-aria-label-part="last" '
# 'data-time="1391039998" data-time-ms="1391039998000" data-long-form="true">29 '
# 'Jan 2014</span></a>\n'
# '</small>\n'
# '\n'
# '          \n'
# '          \n'
# '      </div>\n'
# '\n'
# '\n'
# '      \n'
# '        <p class="TweetTextSize  js-tweet-text tweet-text" lang="en" '
# 'data-aria-label-part="0"><strong>Google</strong> Ends Its Motorola '
# 'Misadventure <a href="http://t.co/5VgcLcV1JH" rel="nofollow" dir="ltr" '
# 'data-expanded-url="http://lnkd.in/dc5Kdih" class="twitter-timeline-link" '
# 'target="_blank" title="http://lnkd.in/dc5Kdih" ><span '
# 'class="tco-ellipsis"></span><span class="invisible">http://</span><span '
# 'class="js-display-url">lnkd.in/dc5Kdih</span><span '
# 'class="invisible"></span><span class="tco-ellipsis"><span '
# 'class="invisible">&nbsp;</span></span></a></p>\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '      \n'
# '      \n'
# '\n'
# '  <div class="expanded-content js-tweet-details-dropdown">\n'
# '    \n'
# '      \n'
# '  </div>\n'
# '\n'
# '\n'
# '      \n'
# '        \n'
# '<div class="stream-item-footer">\n'
# '    \n'
# '      \n'
# '<a class="details with-icn js-details" '
# 'href="/DavidBussin/status/428678940157546496">\n'
# '    <span class="Icon Icon--summary"></span>\n'
# '\n'
# '  <b>\n'
# '      <span class="expand-stream-item js-view-details">View summary</span>\n'
# '      <span class="collapse-stream-item js-hide-details">Hide '
# 'summary</span>\n'
# '  </b>\n'
# '</a>\n'
# '\n'
# '  \n'
# '  \n'
# '      <div class="ProfileTweet-actionCountList u-hiddenVisually">\n'
# '      \n'
# '      <span class="ProfileTweet-action--reply u-hiddenVisually"></span>\n'
# '      <span class="ProfileTweet-action--retweet u-hiddenVisually">\n'
# '        \n'
# '        <span class="ProfileTweet-actionCount" aria-hidden="true" '
# 'data-tweet-stat-count="0">\n'
# '          <span class="ProfileTweet-actionCountForAria" >0 retweets</span>\n'
# '        </span>\n'
# '      </span>\n'
# '      <span class="ProfileTweet-action--favorite u-hiddenVisually">\n'
# '        <span class="ProfileTweet-actionCount" aria-hidden="true" '
# 'data-tweet-stat-count="0">\n'
# '          <span class="ProfileTweet-actionCountForAria" >0 favorites</span>\n'
# '        </span>\n'
# '      </span>\n'
# '    </div>\n'
# '\n'
# '    <div class="ProfileTweet-actionList js-actions " role="group" '
# 'aria-label="Tweet actions">\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--reply">\n'
# '        <button class="ProfileTweet-actionButton u-textUserColorHover '
# 'js-actionButton js-actionReply"\n'
# '          data-modal="ProfileTweet-reply"\n'
# '          type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Reply">\n'
# '            <span class="Icon Icon--reply"></span>\n'
# '            <span class="u-hiddenVisually">Reply</span>\n'
# '          </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--retweet '
# 'js-toggleState js-toggleRt">\n'
# '        <button class="ProfileTweet-actionButton  js-actionButton '
# 'js-actionRetweet"\n'
# '          \n'
# '          data-modal="ProfileTweet-retweet"\n'
# '          type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Retweet">\n'
# '            <span class="Icon Icon--retweet"></span>\n'
# '            <span class="u-hiddenVisually">Retweet</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button><button class="ProfileTweet-actionButtonUndo '
# 'js-actionButton js-actionRetweet" data-modal="ProfileTweet-retweet" '
# 'type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Undo retweet">\n'
# '            <span class="Icon Icon--retweet"></span>\n'
# '            <span class="u-hiddenVisually">Retweeted</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--favorite '
# 'js-toggleState ">\n'
# '        <button class="ProfileTweet-actionButton js-actionButton '
# 'js-actionFavorite" type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Favorite">\n'
# '            <span class="Icon  Icon--favorite"></span>\n'
# '            <span class="u-hiddenVisually">Favorite</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button><button class="ProfileTweet-actionButtonUndo u-linkClean '
# 'js-actionButton js-actionFavorite" type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Undo favorite">\n'
# '            <span class="Icon  Icon--favorite"></span>\n'
# '            <span class="u-hiddenVisually">Favorited</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '\n'
# '      \n'
# '        <div class="ProfileTweet-action ProfileTweet-action--more '
# 'js-more-ProfileTweet-actions">\n'
# '          <div class="dropdown">\n'
# '  <button class="ProfileTweet-actionButton u-textUserColorHover '
# 'dropdown-toggle js-dropdown-toggle" type="button">\n'
# '      <div class="IconContainer js-tooltip" title="More">\n'
# '        <span class="Icon Icon--dots"></span>\n'
# '        <span class="u-hiddenVisually">More</span>\n'
# '      </div>\n'
# '  </button>\n'
# '  <div class="dropdown-menu">\n'
# '  <div class="dropdown-caret">\n'
# '    <div class="caret-outer"></div>\n'
# '    <div class="caret-inner"></div>\n'
# '  </div>\n'
# '  <ul>\n'
# '    \n'
# '      <li class="copy-link-to-tweet js-actionCopyLinkToTweet">\n'
# '        <button type="button" class="dropdown-link">Copy link to '
# 'Tweet</button>\n'
# '      </li>\n'
# '        <li class="embed-link js-actionEmbedTweet" data-nav="embed_tweet">\n'
# '          <button type="button" class="dropdown-link">Embed Tweet</button>\n'
# '        </li>\n'
# '        \n'
# '  </ul>\n'
# '</div>\n'
# '\n'
# '</div>\n'
# '\n'
# '        </div>\n'
# '    </div>\n'
# '\n'
# '</div>\n'
# '\n'
# '\n'
# '\n'
# '      \n'
# '      \n'
# '\n'
# '    </div>\n'
# '  </div>\n'
# '\n'
# '\n'
# '</li>\n'
# '\n'
# '      <li class="js-stream-item stream-item stream-item '
# 'expanding-stream-item\n'
# '" data-item-id="428678939569963008" '
# 'id="stream-item-tweet-428678939569963008" data-item-type="tweet">\n'
# '      \n'
# '\n'
# '\n'
# '  \n'
# '\n'
# '  <div class="tweet original-tweet js-original-tweet js-stream-tweet '
# 'js-actionable-tweet js-profile-popup-actionable  \n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '"\n'
# '    \n'
# 'data-tweet-id="428678939569963008"\n'
# '\n'
# 'data-disclosure-type=""\n'
# 'data-item-id="428678939569963008"\n'
# 'data-permalink-path="/rmi/status/428678939569963008"\n'
# '\n'
# '\n'
# ' data-screen-name="rmi" data-name="Rob Isaac" data-user-id="14372427"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# ' data-is-reply-to="true" \n'
# ' data-has-parent-tweet="true" \n'
# '\n'
# '\n'
# 'data-expanded-footer="&lt;div class=&quot;js-tweet-details-fixer '
# 'tweet-details-fixer&quot;&gt;&#10;&#10;&#10;&#10;        &lt;div '
# 'class=&quot;entities-media-container js-media-container&quot; '
# 'style=&quot;min-height:0px&quot;&gt;&#10;        &lt;/div&gt;&#10;&#10;  '
# '&lt;div '
# 'class=&quot;js-machine-translated-tweet-container&quot;&gt;&lt;/div&gt;&#10;    '
# '&lt;div class=&quot;js-tweet-stats-container tweet-stats-container '
# '&quot;&gt;&#10;    &lt;/div&gt;&#10;&#10;  &lt;div '
# 'class=&quot;client-and-actions&quot;&gt;&#10;  &lt;span '
# 'class=&quot;metadata&quot;&gt;&#10;    &lt;span&gt;3:59 PM - 29 Jan '
# '2014&lt;/span&gt;&#10;&#10;       &amp;middot; &lt;a '
# 'class=&quot;permalink-link js-permalink js-nav&quot; '
# 'href=&quot;/rmi/status/428678939569963008&quot;  '
# 'tabindex=&quot;-1&quot;&gt;Details&lt;/a&gt;&#10;    &#10;&#10;&#10;  '
# '&lt;/span&gt;&#10;&lt;/div&gt;&#10;&#10;&#10;&lt;/div&gt;&#10;"\n'
# '\n'
# '\n'
# ' data-mentions="amiejcp"\n'
# '\n'
# '\n'
# '\n'
# ' data-component-context="tweet"\n'
# ' data-you-follow="false"\n'
# ' data-follows-you="false"\n'
# ' data-you-block="false"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '>\n'
# '\n'
# '\n'
# '    <div class="context">\n'
# '      \n'
# '      \n'
# '\n'
# '    </div>\n'
# '\n'
# '    <div class="content">\n'
# '\n'
# '      \n'
# '      <div class="stream-item-header">\n'
# '          <a  class="account-group js-account-group js-action-profile '
# 'js-user-profile-link js-nav" href="/rmi" data-user-id="14372427">\n'
# '    <img class="avatar js-action-profile-avatar" '
# 'src="https://pbs.twimg.com/profile_images/645150842723504128/GEEeQ59d_bigger.jpg" '
# 'alt="">\n'
# '    <strong class="fullname js-action-profile-name show-popup-with-id" '
# 'data-aria-label-part>Rob Isaac</strong>\n'
# '    <span>&rlm;</span><span class="username js-action-profile-name" '
# 'data-aria-label-part><s>@</s><b>rmi</b></span>\n'
# '    \n'
# '  </a>\n'
# '\n'
# '        <small class="time">\n'
# '  <a href="/rmi/status/428678939569963008" class="tweet-timestamp '
# 'js-permalink js-nav js-tooltip" title="3:59 PM - 29 Jan 2014" ><span '
# 'class="_timestamp js-short-timestamp " data-aria-label-part="last" '
# 'data-time="1391039998" data-time-ms="1391039998000" data-long-form="true">29 '
# 'Jan 2014</span></a>\n'
# '</small>\n'
# '\n'
# '          \n'
# '          \n'
# '      </div>\n'
# '\n'
# '\n'
# '      \n'
# '        <p class="TweetTextSize  js-tweet-text tweet-text" lang="en" '
# 'data-aria-label-part="0"><a href="/amiejcp" class="twitter-atreply '
# 'pretty-link js-nav" dir="ltr" ><s>@</s><b>amiejcp</b></a> For new fibre '
# 'installs, <strong>Google</strong> for &quot;mdu consent chorus&quot;. For '
# 'older copper, the body corp agreement for the building.</p>\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '      \n'
# '      \n'
# '\n'
# '  <div class="expanded-content js-tweet-details-dropdown">\n'
# '    \n'
# '      \n'
# '  </div>\n'
# '\n'
# '\n'
# '      \n'
# '        \n'
# '<div class="stream-item-footer">\n'
# '    \n'
# '      \n'
# '<a class="details with-icn js-details" '
# 'href="/rmi/status/428678939569963008">\n'
# '        <span class="Icon Icon--conversation"></span>\n'
# '  \n'
# '  <b>\n'
# '      <span class="expand-stream-item js-view-details">View '
# 'conversation</span>\n'
# '      <span class="collapse-stream-item js-hide-details">Hide '
# 'conversation</span>\n'
# '  </b>\n'
# '</a>\n'
# '\n'
# '  \n'
# '  \n'
# '      <div class="ProfileTweet-actionCountList u-hiddenVisually">\n'
# '      \n'
# '      <span class="ProfileTweet-action--reply u-hiddenVisually"></span>\n'
# '      <span class="ProfileTweet-action--retweet u-hiddenVisually">\n'
# '        \n'
# '        <span class="ProfileTweet-actionCount" aria-hidden="true" '
# 'data-tweet-stat-count="0">\n'
# '          <span class="ProfileTweet-actionCountForAria" >0 retweets</span>\n'
# '        </span>\n'
# '      </span>\n'
# '      <span class="ProfileTweet-action--favorite u-hiddenVisually">\n'
# '        <span class="ProfileTweet-actionCount" aria-hidden="true" '
# 'data-tweet-stat-count="0">\n'
# '          <span class="ProfileTweet-actionCountForAria" >0 favorites</span>\n'
# '        </span>\n'
# '      </span>\n'
# '    </div>\n'
# '\n'
# '    <div class="ProfileTweet-actionList js-actions " role="group" '
# 'aria-label="Tweet actions">\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--reply">\n'
# '        <button class="ProfileTweet-actionButton u-textUserColorHover '
# 'js-actionButton js-actionReply"\n'
# '          data-modal="ProfileTweet-reply"\n'
# '          type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Reply">\n'
# '            <span class="Icon Icon--reply"></span>\n'
# '            <span class="u-hiddenVisually">Reply</span>\n'
# '          </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--retweet '
# 'js-toggleState js-toggleRt">\n'
# '        <button class="ProfileTweet-actionButton  js-actionButton '
# 'js-actionRetweet"\n'
# '          \n'
# '          data-modal="ProfileTweet-retweet"\n'
# '          type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Retweet">\n'
# '            <span class="Icon Icon--retweet"></span>\n'
# '            <span class="u-hiddenVisually">Retweet</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button><button class="ProfileTweet-actionButtonUndo '
# 'js-actionButton js-actionRetweet" data-modal="ProfileTweet-retweet" '
# 'type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Undo retweet">\n'
# '            <span class="Icon Icon--retweet"></span>\n'
# '            <span class="u-hiddenVisually">Retweeted</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--favorite '
# 'js-toggleState ">\n'
# '        <button class="ProfileTweet-actionButton js-actionButton '
# 'js-actionFavorite" type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Favorite">\n'
# '            <span class="Icon  Icon--favorite"></span>\n'
# '            <span class="u-hiddenVisually">Favorite</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button><button class="ProfileTweet-actionButtonUndo u-linkClean '
# 'js-actionButton js-actionFavorite" type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Undo favorite">\n'
# '            <span class="Icon  Icon--favorite"></span>\n'
# '            <span class="u-hiddenVisually">Favorited</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '\n'
# '      \n'
# '        <div class="ProfileTweet-action ProfileTweet-action--more '
# 'js-more-ProfileTweet-actions">\n'
# '          <div class="dropdown">\n'
# '  <button class="ProfileTweet-actionButton u-textUserColorHover '
# 'dropdown-toggle js-dropdown-toggle" type="button">\n'
# '      <div class="IconContainer js-tooltip" title="More">\n'
# '        <span class="Icon Icon--dots"></span>\n'
# '        <span class="u-hiddenVisually">More</span>\n'
# '      </div>\n'
# '  </button>\n'
# '  <div class="dropdown-menu">\n'
# '  <div class="dropdown-caret">\n'
# '    <div class="caret-outer"></div>\n'
# '    <div class="caret-inner"></div>\n'
# '  </div>\n'
# '  <ul>\n'
# '    \n'
# '      <li class="copy-link-to-tweet js-actionCopyLinkToTweet">\n'
# '        <button type="button" class="dropdown-link">Copy link to '
# 'Tweet</button>\n'
# '      </li>\n'
# '        <li class="embed-link js-actionEmbedTweet" data-nav="embed_tweet">\n'
# '          <button type="button" class="dropdown-link">Embed Tweet</button>\n'
# '        </li>\n'
# '        \n'
# '  </ul>\n'
# '</div>\n'
# '\n'
# '</div>\n'
# '\n'
# '        </div>\n'
# '    </div>\n'
# '\n'
# '</div>\n'
# '\n'
# '\n'
# '\n'
# '      \n'
# '      \n'
# '\n'
# '    </div>\n'
# '  </div>\n'
# '\n'
# '\n'
# '</li>\n'
# '\n'
# '      <li class="js-stream-item stream-item stream-item '
# 'expanding-stream-item\n'
# '" data-item-id="428678937305051136" '
# 'id="stream-item-tweet-428678937305051136" data-item-type="tweet">\n'
# '      \n'
# '\n'
# '\n'
# '  \n'
# '\n'
# '  <div class="tweet original-tweet js-original-tweet js-stream-tweet '
# 'js-actionable-tweet js-profile-popup-actionable  \n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '"\n'
# '    \n'
# 'data-tweet-id="428678937305051136"\n'
# '\n'
# 'data-disclosure-type=""\n'
# 'data-item-id="428678937305051136"\n'
# 'data-permalink-path="/Track_WWE_News/status/428678937305051136"\n'
# '\n'
# '\n'
# ' data-screen-name="Track_WWE_News" data-name="WWE News" '
# 'data-user-id="355553308"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# 'data-expanded-footer="&lt;div class=&quot;js-tweet-details-fixer '
# 'tweet-details-fixer&quot;&gt;&#10;&#10;&#10;&#10;        &lt;div '
# 'class=&quot;entities-media-container js-media-container&quot; '
# 'style=&quot;min-height:0px&quot;&gt;&#10;        &lt;/div&gt;&#10;&#10;  '
# '&lt;div '
# 'class=&quot;js-machine-translated-tweet-container&quot;&gt;&lt;/div&gt;&#10;    '
# '&lt;div class=&quot;js-tweet-stats-container tweet-stats-container '
# '&quot;&gt;&#10;    &lt;/div&gt;&#10;&#10;  &lt;div '
# 'class=&quot;client-and-actions&quot;&gt;&#10;  &lt;span '
# 'class=&quot;metadata&quot;&gt;&#10;    &lt;span&gt;3:59 PM - 29 Jan '
# '2014&lt;/span&gt;&#10;&#10;       &amp;middot; &lt;a '
# 'class=&quot;permalink-link js-permalink js-nav&quot; '
# 'href=&quot;/Track_WWE_News/status/428678937305051136&quot;  '
# 'tabindex=&quot;-1&quot;&gt;Details&lt;/a&gt;&#10;    &#10;&#10;&#10;  '
# '&lt;/span&gt;&#10;&lt;/div&gt;&#10;&#10;&#10;&lt;/div&gt;&#10;"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# ' data-component-context="tweet"\n'
# ' data-you-follow="false"\n'
# ' data-follows-you="false"\n'
# ' data-you-block="false"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '>\n'
# '\n'
# '\n'
# '    <div class="context">\n'
# '      \n'
# '      \n'
# '\n'
# '    </div>\n'
# '\n'
# '    <div class="content">\n'
# '\n'
# '      \n'
# '      <div class="stream-item-header">\n'
# '          <a  class="account-group js-account-group js-action-profile '
# 'js-user-profile-link js-nav" href="/Track_WWE_News" '
# 'data-user-id="355553308">\n'
# '    <img class="avatar js-action-profile-avatar" '
# 'src="https://pbs.twimg.com/profile_images/1497419250/wwe-logo_bigger.jpg" '
# 'alt="">\n'
# '    <strong class="fullname js-action-profile-name show-popup-with-id" '
# 'data-aria-label-part>WWE News</strong>\n'
# '    <span>&rlm;</span><span class="username js-action-profile-name" '
# 'data-aria-label-part><s>@</s><b>Track_WWE_News</b></span>\n'
# '    \n'
# '  </a>\n'
# '\n'
# '        <small class="time">\n'
# '  <a href="/Track_WWE_News/status/428678937305051136" class="tweet-timestamp '
# 'js-permalink js-nav js-tooltip" title="3:59 PM - 29 Jan 2014" ><span '
# 'class="_timestamp js-short-timestamp " data-aria-label-part="last" '
# 'data-time="1391039997" data-time-ms="1391039997000" data-long-form="true">29 '
# 'Jan 2014</span></a>\n'
# '</small>\n'
# '\n'
# '          \n'
# '          \n'
# '      </div>\n'
# '\n'
# '\n'
# '      \n'
# '        <p class="TweetTextSize  js-tweet-text tweet-text" lang="en" '
# 'data-aria-label-part="0"><strong>Google</strong> sells Motorola Mobility to '
# 'Lenovo for $2.91 billion - Washington Post.. <a '
# 'href="http://t.co/3WM4kzioAB" rel="nofollow" dir="ltr" '
# 'data-expanded-url="http://q.gs/5UlQQ" class="twitter-timeline-link" '
# 'target="_blank" title="http://q.gs/5UlQQ" ><span '
# 'class="tco-ellipsis"></span><span class="invisible">http://</span><span '
# 'class="js-display-url">q.gs/5UlQQ</span><span class="invisible"></span><span '
# 'class="tco-ellipsis"><span class="invisible">&nbsp;</span></span></a> <a '
# 'href="/hashtag/WWE?src=hash" data-query-source="hashtag_click" '
# 'class="twitter-hashtag pretty-link js-nav" dir="ltr" '
# '><s>#</s><b>WWE</b></a></p>\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '      \n'
# '      \n'
# '\n'
# '  <div class="expanded-content js-tweet-details-dropdown">\n'
# '    \n'
# '      \n'
# '  </div>\n'
# '\n'
# '\n'
# '      \n'
# '        \n'
# '<div class="stream-item-footer">\n'
# '    \n'
# '  \n'
# '  \n'
# '      <div class="ProfileTweet-actionCountList u-hiddenVisually">\n'
# '      \n'
# '      <span class="ProfileTweet-action--reply u-hiddenVisually"></span>\n'
# '      <span class="ProfileTweet-action--retweet u-hiddenVisually">\n'
# '        \n'
# '        <span class="ProfileTweet-actionCount"  data-tweet-stat-count="1">\n'
# '          <span class="ProfileTweet-actionCountForAria" '
# 'data-aria-label-part>1 retweet</span>\n'
# '        </span>\n'
# '      </span>\n'
# '      <span class="ProfileTweet-action--favorite u-hiddenVisually">\n'
# '        <span class="ProfileTweet-actionCount" aria-hidden="true" '
# 'data-tweet-stat-count="0">\n'
# '          <span class="ProfileTweet-actionCountForAria" >0 favorites</span>\n'
# '        </span>\n'
# '      </span>\n'
# '    </div>\n'
# '\n'
# '    <div class="ProfileTweet-actionList js-actions " role="group" '
# 'aria-label="Tweet actions">\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--reply">\n'
# '        <button class="ProfileTweet-actionButton u-textUserColorHover '
# 'js-actionButton js-actionReply"\n'
# '          data-modal="ProfileTweet-reply"\n'
# '          type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Reply">\n'
# '            <span class="Icon Icon--reply"></span>\n'
# '            <span class="u-hiddenVisually">Reply</span>\n'
# '          </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--retweet '
# 'js-toggleState js-toggleRt">\n'
# '        <button class="ProfileTweet-actionButton  js-actionButton '
# 'js-actionRetweet"\n'
# '          \n'
# '          data-modal="ProfileTweet-retweet"\n'
# '          type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Retweet">\n'
# '            <span class="Icon Icon--retweet"></span>\n'
# '            <span class="u-hiddenVisually">Retweet</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true">1</span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button><button class="ProfileTweet-actionButtonUndo '
# 'js-actionButton js-actionRetweet" data-modal="ProfileTweet-retweet" '
# 'type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Undo retweet">\n'
# '            <span class="Icon Icon--retweet"></span>\n'
# '            <span class="u-hiddenVisually">Retweeted</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true">1</span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--favorite '
# 'js-toggleState ">\n'
# '        <button class="ProfileTweet-actionButton js-actionButton '
# 'js-actionFavorite" type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Favorite">\n'
# '            <span class="Icon  Icon--favorite"></span>\n'
# '            <span class="u-hiddenVisually">Favorite</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button><button class="ProfileTweet-actionButtonUndo u-linkClean '
# 'js-actionButton js-actionFavorite" type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Undo favorite">\n'
# '            <span class="Icon  Icon--favorite"></span>\n'
# '            <span class="u-hiddenVisually">Favorited</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '\n'
# '      \n'
# '        <div class="ProfileTweet-action ProfileTweet-action--more '
# 'js-more-ProfileTweet-actions">\n'
# '          <div class="dropdown">\n'
# '  <button class="ProfileTweet-actionButton u-textUserColorHover '
# 'dropdown-toggle js-dropdown-toggle" type="button">\n'
# '      <div class="IconContainer js-tooltip" title="More">\n'
# '        <span class="Icon Icon--dots"></span>\n'
# '        <span class="u-hiddenVisually">More</span>\n'
# '      </div>\n'
# '  </button>\n'
# '  <div class="dropdown-menu">\n'
# '  <div class="dropdown-caret">\n'
# '    <div class="caret-outer"></div>\n'
# '    <div class="caret-inner"></div>\n'
# '  </div>\n'
# '  <ul>\n'
# '    \n'
# '      <li class="copy-link-to-tweet js-actionCopyLinkToTweet">\n'
# '        <button type="button" class="dropdown-link">Copy link to '
# 'Tweet</button>\n'
# '      </li>\n'
# '        <li class="embed-link js-actionEmbedTweet" data-nav="embed_tweet">\n'
# '          <button type="button" class="dropdown-link">Embed Tweet</button>\n'
# '        </li>\n'
# '        \n'
# '  </ul>\n'
# '</div>\n'
# '\n'
# '</div>\n'
# '\n'
# '        </div>\n'
# '    </div>\n'
# '\n'
# '</div>\n'
# '\n'
# '\n'
# '\n'
# '      \n'
# '      \n'
# '\n'
# '    </div>\n'
# '  </div>\n'
# '\n'
# '\n'
# '</li>\n'
# '\n'
# '      <li class="js-stream-item stream-item stream-item '
# 'expanding-stream-item\n'
# '" data-item-id="428678934616473600" '
# 'id="stream-item-tweet-428678934616473600" data-item-type="tweet">\n'
# '      \n'
# '\n'
# '\n'
# '  \n'
# '\n'
# '  <div class="tweet original-tweet js-original-tweet js-stream-tweet '
# 'js-actionable-tweet js-profile-popup-actionable  \n'
# '\n'
# '\n'
# '\n'
# ' has-cards\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '"\n'
# '    \n'
# 'data-tweet-id="428678934616473600"\n'
# '\n'
# 'data-disclosure-type=""\n'
# 'data-item-id="428678934616473600"\n'
# 'data-permalink-path="/asimmushtaqch/status/428678934616473600"\n'
# '\n'
# '\n'
# ' data-screen-name="asimmushtaqch" data-name="Asim Mushtaq Ch" '
# 'data-user-id="146146371"\n'
# '\n'
# '\n'
# '\n'
# ' data-has-cards="true"\n'
# '\n'
# 'data-card2-type="summary_large_image"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# 'data-expanded-footer="&lt;div class=&quot;js-tweet-details-fixer '
# 'tweet-details-fixer&quot;&gt;&#10;&#10;            &lt;div class=&quot;card2 '
# 'js-media-container portrait&quot; '
# 'data-card2-name=&quot;summary_large_image&quot;&gt;&#10;    &#10;    &lt;div '
# 'class=&quot;js-macaw-cards-iframe-container&quot;&#10;  '
# 'data-src=&quot;/i/cards/tfw/v1/428678934616473600?cardname=summary_large_image&amp;amp;earned=true&amp;amp;lang=en&quot;&#10;  '
# 'data-autoplay-src=&quot;/i/cards/tfw/v1/428678934616473600?cardname=summary_large_image&amp;amp;earned=true&amp;amp;lang=en&quot;&#10;  '
# 'data-card-name=&quot;summary_large_image&quot;&#10;  '
# 'data-card-url=&quot;http://t.co/RXGcRpAwAI&quot;&#10;  '
# 'data-publisher-id=&quot;972651&quot;&#10;  '
# 'data-creator-id=&quot;&quot;&#10;  '
# 'data-amplify-content-id=&quot;&quot;&#10;  '
# 'data-amplify-playlist-url=&quot;&quot;&#10;  '
# 'data-full-card-iframe-url=&quot;/i/cards/tfw/v1/428678934616473600?cardname=summary_large_image&amp;amp;earned=true&amp;amp;lang=en&quot;&#10;  '
# 'data-has-autoplayable-media=&quot;false&quot;&gt;&#10;&lt;/div&gt;&#10;&#10;&lt;/div&gt;&#10;&#10;&#10;&#10;        '
# '&lt;div class=&quot;entities-media-container js-media-container&quot; '
# 'style=&quot;min-height:0px&quot;&gt;&#10;        &lt;/div&gt;&#10;&#10;  '
# '&lt;div '
# 'class=&quot;js-machine-translated-tweet-container&quot;&gt;&lt;/div&gt;&#10;    '
# '&lt;div class=&quot;js-tweet-stats-container tweet-stats-container '
# '&quot;&gt;&#10;    &lt;/div&gt;&#10;&#10;  &lt;div '
# 'class=&quot;client-and-actions&quot;&gt;&#10;  &lt;span '
# 'class=&quot;metadata&quot;&gt;&#10;    &lt;span&gt;3:59 PM - 29 Jan '
# '2014&lt;/span&gt;&#10;&#10;       &amp;middot; &lt;a '
# 'class=&quot;permalink-link js-permalink js-nav&quot; '
# 'href=&quot;/asimmushtaqch/status/428678934616473600&quot;  '
# 'tabindex=&quot;-1&quot;&gt;Details&lt;/a&gt;&#10;    &#10;&#10;&#10;  '
# '&lt;/span&gt;&#10;&lt;/div&gt;&#10;&#10;&#10;&lt;/div&gt;&#10;"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# ' data-component-context="tweet"\n'
# ' data-you-follow="false"\n'
# ' data-follows-you="false"\n'
# ' data-you-block="false"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '>\n'
# '\n'
# '\n'
# '    <div class="context">\n'
# '      \n'
# '      \n'
# '\n'
# '    </div>\n'
# '\n'
# '    <div class="content">\n'
# '\n'
# '      \n'
# '      <div class="stream-item-header">\n'
# '          <a  class="account-group js-account-group js-action-profile '
# 'js-user-profile-link js-nav" href="/asimmushtaqch" '
# 'data-user-id="146146371">\n'
# '    <img class="avatar js-action-profile-avatar" '
# 'src="https://pbs.twimg.com/profile_images/637519879399075840/yZ_API2X_bigger.jpg" '
# 'alt="">\n'
# '    <strong class="fullname js-action-profile-name show-popup-with-id" '
# 'data-aria-label-part>Asim Mushtaq Ch</strong>\n'
# '    <span>&rlm;</span><span class="username js-action-profile-name" '
# 'data-aria-label-part><s>@</s><b>asimmushtaqch</b></span>\n'
# '    \n'
# '  </a>\n'
# '\n'
# '        <small class="time">\n'
# '  <a href="/asimmushtaqch/status/428678934616473600" class="tweet-timestamp '
# 'js-permalink js-nav js-tooltip" title="3:59 PM - 29 Jan 2014" ><span '
# 'class="_timestamp js-short-timestamp " data-aria-label-part="last" '
# 'data-time="1391039997" data-time-ms="1391039997000" data-long-form="true">29 '
# 'Jan 2014</span></a>\n'
# '</small>\n'
# '\n'
# '          \n'
# '          \n'
# '      </div>\n'
# '\n'
# '\n'
# '      \n'
# '        <p class="TweetTextSize  js-tweet-text tweet-text" lang="en" '
# 'data-aria-label-part="0">Lenovo Buys <strong>Google</strong>&#39;s Motorola '
# 'Unit for $2.9 Billion <a href="http://t.co/RXGcRpAwAI" rel="nofollow" '
# 'dir="ltr" data-expanded-url="http://dlvr.it/4pg63T" '
# 'class="twitter-timeline-link" target="_blank" title="http://dlvr.it/4pg63T" '
# '><span class="tco-ellipsis"></span><span '
# 'class="invisible">http://</span><span '
# 'class="js-display-url">dlvr.it/4pg63T</span><span '
# 'class="invisible"></span><span class="tco-ellipsis"><span '
# 'class="invisible">&nbsp;</span></span></a></p>\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '      \n'
# '      \n'
# '\n'
# '  <div class="expanded-content js-tweet-details-dropdown">\n'
# '    \n'
# '      \n'
# '  </div>\n'
# '\n'
# '\n'
# '      \n'
# '        \n'
# '<div class="stream-item-footer">\n'
# '    \n'
# '      \n'
# '<a class="details with-icn js-details" '
# 'href="/asimmushtaqch/status/428678934616473600">\n'
# '    <span class="Icon Icon--summary"></span>\n'
# '\n'
# '  <b>\n'
# '      <span class="expand-stream-item js-view-details">View summary</span>\n'
# '      <span class="collapse-stream-item js-hide-details">Hide '
# 'summary</span>\n'
# '  </b>\n'
# '</a>\n'
# '\n'
# '  \n'
# '  \n'
# '      <div class="ProfileTweet-actionCountList u-hiddenVisually">\n'
# '      \n'
# '      <span class="ProfileTweet-action--reply u-hiddenVisually"></span>\n'
# '      <span class="ProfileTweet-action--retweet u-hiddenVisually">\n'
# '        \n'
# '        <span class="ProfileTweet-actionCount" aria-hidden="true" '
# 'data-tweet-stat-count="0">\n'
# '          <span class="ProfileTweet-actionCountForAria" >0 retweets</span>\n'
# '        </span>\n'
# '      </span>\n'
# '      <span class="ProfileTweet-action--favorite u-hiddenVisually">\n'
# '        <span class="ProfileTweet-actionCount" aria-hidden="true" '
# 'data-tweet-stat-count="0">\n'
# '          <span class="ProfileTweet-actionCountForAria" >0 favorites</span>\n'
# '        </span>\n'
# '      </span>\n'
# '    </div>\n'
# '\n'
# '    <div class="ProfileTweet-actionList js-actions " role="group" '
# 'aria-label="Tweet actions">\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--reply">\n'
# '        <button class="ProfileTweet-actionButton u-textUserColorHover '
# 'js-actionButton js-actionReply"\n'
# '          data-modal="ProfileTweet-reply"\n'
# '          type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Reply">\n'
# '            <span class="Icon Icon--reply"></span>\n'
# '            <span class="u-hiddenVisually">Reply</span>\n'
# '          </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--retweet '
# ...
# '          </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--retweet '
# 'js-toggleState js-toggleRt">\n'
# '        <button class="ProfileTweet-actionButton  js-actionButton '
# 'js-actionRetweet"\n'
# '          \n'
# '          data-modal="ProfileTweet-retweet"\n'
# '          type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Retweet">\n'
# '            <span class="Icon Icon--retweet"></span>\n'
# '            <span class="u-hiddenVisually">Retweet</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button><button class="ProfileTweet-actionButtonUndo '
# 'js-actionButton js-actionRetweet" data-modal="ProfileTweet-retweet" '
# 'type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Undo retweet">\n'
# '            <span class="Icon Icon--retweet"></span>\n'
# '            <span class="u-hiddenVisually">Retweeted</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--favorite '
# 'js-toggleState ">\n'
# '        <button class="ProfileTweet-actionButton js-actionButton '
# 'js-actionFavorite" type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Favorite">\n'
# '            <span class="Icon  Icon--favorite"></span>\n'
# '            <span class="u-hiddenVisually">Favorite</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button><button class="ProfileTweet-actionButtonUndo u-linkClean '
# 'js-actionButton js-actionFavorite" type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Undo favorite">\n'
# '            <span class="Icon  Icon--favorite"></span>\n'
# '            <span class="u-hiddenVisually">Favorited</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '\n'
# '      \n'
# '        <div class="ProfileTweet-action ProfileTweet-action--more '
# 'js-more-ProfileTweet-actions">\n'
# '          <div class="dropdown">\n'
# '  <button class="ProfileTweet-actionButton u-textUserColorHover '
# 'dropdown-toggle js-dropdown-toggle" type="button">\n'
# '      <div class="IconContainer js-tooltip" title="More">\n'
# '        <span class="Icon Icon--dots"></span>\n'
# '        <span class="u-hiddenVisually">More</span>\n'
# '      </div>\n'
# '  </button>\n'
# '  <div class="dropdown-menu">\n'
# '  <div class="dropdown-caret">\n'
# '    <div class="caret-outer"></div>\n'
# '    <div class="caret-inner"></div>\n'
# '  </div>\n'
# '  <ul>\n'
# '    \n'
# '      <li class="copy-link-to-tweet js-actionCopyLinkToTweet">\n'
# '        <button type="button" class="dropdown-link">Copy link to '
# 'Tweet</button>\n'
# '      </li>\n'
# '        <li class="embed-link js-actionEmbedTweet" data-nav="embed_tweet">\n'
# '          <button type="button" class="dropdown-link">Embed Tweet</button>\n'
# '        </li>\n'
# '        \n'
# '  </ul>\n'
# '</div>\n'
# '\n'
# '</div>\n'
# '\n'
# '        </div>\n'
# '    </div>\n'
# '\n'
# '</div>\n'
# '\n'
# '\n'
# '\n'
# '      \n'
# '      \n'
# '\n'
# '    </div>\n'
# '  </div>\n'
# '\n'
# '\n'
# '</li>\n'
# '\n'
# '      <li class="js-stream-item stream-item stream-item '
# 'expanding-stream-item\n'
# '" data-item-id="428678916245815296" '
# 'id="stream-item-tweet-428678916245815296" data-item-type="tweet">\n'
# '      \n'
# '\n'
# '\n'
# '  \n'
# '\n'
# '  <div class="tweet original-tweet js-original-tweet js-stream-tweet '
# 'js-actionable-tweet js-profile-popup-actionable  \n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '"\n'
# '    \n'
# 'data-tweet-id="428678916245815296"\n'
# '\n'
# 'data-disclosure-type=""\n'
# 'data-item-id="428678916245815296"\n'
# 'data-permalink-path="/the_Midus_Touch/status/428678916245815296"\n'
# '\n'
# '\n'
# ' data-screen-name="the_Midus_Touch" data-name="Tweetaleet baby" '
# 'data-user-id="495374092"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# ' data-is-reply-to="true" \n'
# ' data-has-parent-tweet="true" \n'
# '\n'
# '\n'
# 'data-expanded-footer="&lt;div class=&quot;js-tweet-details-fixer '
# 'tweet-details-fixer&quot;&gt;&#10;&#10;&#10;&#10;        &lt;div '
# 'class=&quot;entities-media-container js-media-container&quot; '
# 'style=&quot;min-height:0px&quot;&gt;&#10;        &lt;/div&gt;&#10;&#10;  '
# '&lt;div '
# 'class=&quot;js-machine-translated-tweet-container&quot;&gt;&lt;/div&gt;&#10;    '
# '&lt;div class=&quot;js-tweet-stats-container tweet-stats-container '
# '&quot;&gt;&#10;    &lt;/div&gt;&#10;&#10;  &lt;div '
# 'class=&quot;client-and-actions&quot;&gt;&#10;  &lt;span '
# 'class=&quot;metadata&quot;&gt;&#10;    &lt;span&gt;3:59 PM - 29 Jan '
# '2014&lt;/span&gt;&#10;&#10;       &amp;middot; &lt;a '
# 'class=&quot;permalink-link js-permalink js-nav&quot; '
# 'href=&quot;/the_Midus_Touch/status/428678916245815296&quot;  '
# 'tabindex=&quot;-1&quot;&gt;Details&lt;/a&gt;&#10;    &#10;&#10;&#10;  '
# '&lt;/span&gt;&#10;&lt;/div&gt;&#10;&#10;&#10;&lt;/div&gt;&#10;"\n'
# '\n'
# '\n'
# ' data-mentions="_FiveeeeOhhhh"\n'
# '\n'
# '\n'
# '\n'
# ' data-component-context="tweet"\n'
# ' data-you-follow="false"\n'
# ' data-follows-you="false"\n'
# ' data-you-block="false"\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '>\n'
# '\n'
# '\n'
# '    <div class="context">\n'
# '      \n'
# '      \n'
# '\n'
# '    </div>\n'
# '\n'
# '    <div class="content">\n'
# '\n'
# '      \n'
# '      <div class="stream-item-header">\n'
# '          <a  class="account-group js-account-group js-action-profile '
# 'js-user-profile-link js-nav" href="/the_Midus_Touch" '
# 'data-user-id="495374092">\n'
# '    <img class="avatar js-action-profile-avatar" '
# 'src="https://pbs.twimg.com/profile_images/566998933793021953/8DhZUDRl_bigger.jpeg" '
# 'alt="">\n'
# '    <strong class="fullname js-action-profile-name show-popup-with-id" '
# 'data-aria-label-part>Tweetaleet baby</strong>\n'
# '    <span>&rlm;</span><span class="username js-action-profile-name" '
# 'data-aria-label-part><s>@</s><b>the_Midus_Touch</b></span>\n'
# '    \n'
# '  </a>\n'
# '\n'
# '        <small class="time">\n'
# '  <a href="/the_Midus_Touch/status/428678916245815296" '
# 'class="tweet-timestamp js-permalink js-nav js-tooltip" title="3:59 PM - 29 '
# 'Jan 2014" ><span class="_timestamp js-short-timestamp " '
# 'data-aria-label-part="last" data-time="1391039992" '
# 'data-time-ms="1391039992000" data-long-form="true">29 Jan 2014</span></a>\n'
# '</small>\n'
# '\n'
# '          \n'
# '          \n'
# '      </div>\n'
# '\n'
# '\n'
# '      \n'
# '        <p class="TweetTextSize  js-tweet-text tweet-text" lang="en" '
# 'data-aria-label-part="0"><a href="/_FiveeeeOhhhh" class="twitter-atreply '
# 'pretty-link js-nav" dir="ltr" ><s>@</s><b>_FiveeeeOhhhh</b></a> '
# '<strong>google</strong></p>\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '      \n'
# '      \n'
# '\n'
# '  <div class="expanded-content js-tweet-details-dropdown">\n'
# '    \n'
# '      \n'
# '  </div>\n'
# '\n'
# '\n'
# '      \n'
# '        \n'
# '<div class="stream-item-footer">\n'
# '    \n'
# '      \n'
# '<a class="details with-icn js-details" '
# 'href="/the_Midus_Touch/status/428678916245815296">\n'
# '        <span class="Icon Icon--conversation"></span>\n'
# '  \n'
# '  <b>\n'
# '      <span class="expand-stream-item js-view-details">View '
# 'conversation</span>\n'
# '      <span class="collapse-stream-item js-hide-details">Hide '
# 'conversation</span>\n'
# '  </b>\n'
# '</a>\n'
# '\n'
# '  \n'
# '  \n'
# '      <div class="ProfileTweet-actionCountList u-hiddenVisually">\n'
# '      \n'
# '      <span class="ProfileTweet-action--reply u-hiddenVisually"></span>\n'
# '      <span class="ProfileTweet-action--retweet u-hiddenVisually">\n'
# '        \n'
# '        <span class="ProfileTweet-actionCount" aria-hidden="true" '
# 'data-tweet-stat-count="0">\n'
# '          <span class="ProfileTweet-actionCountForAria" >0 retweets</span>\n'
# '        </span>\n'
# '      </span>\n'
# '      <span class="ProfileTweet-action--favorite u-hiddenVisually">\n'
# '        <span class="ProfileTweet-actionCount" aria-hidden="true" '
# 'data-tweet-stat-count="0">\n'
# '          <span class="ProfileTweet-actionCountForAria" >0 favorites</span>\n'
# '        </span>\n'
# '      </span>\n'
# '    </div>\n'
# '\n'
# '    <div class="ProfileTweet-actionList js-actions " role="group" '
# 'aria-label="Tweet actions">\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--reply">\n'
# '        <button class="ProfileTweet-actionButton u-textUserColorHover '
# 'js-actionButton js-actionReply"\n'
# '          data-modal="ProfileTweet-reply"\n'
# '          type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Reply">\n'
# '            <span class="Icon Icon--reply"></span>\n'
# '            <span class="u-hiddenVisually">Reply</span>\n'
# '          </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--retweet '
# 'js-toggleState js-toggleRt">\n'
# '        <button class="ProfileTweet-actionButton  js-actionButton '
# 'js-actionRetweet"\n'
# '          \n'
# '          data-modal="ProfileTweet-retweet"\n'
# '          type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Retweet">\n'
# '            <span class="Icon Icon--retweet"></span>\n'
# '            <span class="u-hiddenVisually">Retweet</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button><button class="ProfileTweet-actionButtonUndo '
# 'js-actionButton js-actionRetweet" data-modal="ProfileTweet-retweet" '
# 'type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Undo retweet">\n'
# '            <span class="Icon Icon--retweet"></span>\n'
# '            <span class="u-hiddenVisually">Retweeted</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '      <div class="ProfileTweet-action ProfileTweet-action--favorite '
# 'js-toggleState ">\n'
# '        <button class="ProfileTweet-actionButton js-actionButton '
# 'js-actionFavorite" type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Favorite">\n'
# '            <span class="Icon  Icon--favorite"></span>\n'
# '            <span class="u-hiddenVisually">Favorite</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button><button class="ProfileTweet-actionButtonUndo u-linkClean '
# 'js-actionButton js-actionFavorite" type="button">\n'
# '          <div class="IconContainer js-tooltip" title="Undo favorite">\n'
# '            <span class="Icon  Icon--favorite"></span>\n'
# '            <span class="u-hiddenVisually">Favorited</span>\n'
# '          </div>\n'
# '            <div class="IconTextContainer">\n'
# '              <span class="ProfileTweet-actionCount '
# 'ProfileTweet-actionCount--isZero">\n'
# '                <span class="ProfileTweet-actionCountForPresentation" '
# 'aria-hidden="true"></span>\n'
# '              </span>\n'
# '            </div>\n'
# '        </button>\n'
# '      </div>\n'
# '\n'
# '      \n'
# '\n'
# '      \n'
# '        <div class="ProfileTweet-action ProfileTweet-action--more '
# 'js-more-ProfileTweet-actions">\n'
# '          <div class="dropdown">\n'
# '  <button class="ProfileTweet-actionButton u-textUserColorHover '
# 'dropdown-toggle js-dropdown-toggle" type="button">\n'
# '      <div class="IconContainer js-tooltip" title="More">\n'
# '        <span class="Icon Icon--dots"></span>\n'
# '        <span class="u-hiddenVisually">More</span>\n'
# '      </div>\n'
# '  </button>\n'
# '  <div class="dropdown-menu">\n'
# '  <div class="dropdown-caret">\n'
# '    <div class="caret-outer"></div>\n'
# '    <div class="caret-inner"></div>\n'
# '  </div>\n'
# '  <ul>\n'
# '    \n'
# '      <li class="copy-link-to-tweet js-actionCopyLinkToTweet">\n'
# '        <button type="button" class="dropdown-link">Copy link to '
# 'Tweet</button>\n'
# '      </li>\n'
# '        <li class="embed-link js-actionEmbedTweet" data-nav="embed_tweet">\n'
# '          <button type="button" class="dropdown-link">Embed Tweet</button>\n'
# '        </li>\n'
# '        \n'
# '  </ul>\n'
# '</div>\n'
# '\n'
# '</div>\n'
# '\n'
# '        </div>\n'
# '    </div>\n'
# '\n'
# '</div>\n'
# '\n'
# '\n'
# '\n'
# '      \n'
# '      \n'
# '\n'
# '    </div>\n'
# '  </div>\n'
# '\n'
# '\n'
# '</li>\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# 181089
# Google sells Motorola to Lenovo.  WTF, I just bought a Moto G! http://cnet.co/1dP8DAJ
#
#
# Google Ends Its Motorola Misadventure http://lnkd.in/dc5Kdih
#
#
# @amiejcp For new fibre installs, Google for "mdu consent chorus". For older copper, the body corp agreement for the building.
#
#
# Google sells Motorola Mobility to Lenovo for $2.91 billion - Washington Post.. http://q.gs/5UlQQ  #WWE
#
#
# Lenovo Buys Google's Motorola Unit for $2.9 Billion http://dlvr.it/4pg63T
#
#
# RT @NewsBreaker: JUST IN: @lenovo buys Motorola Mobility from @google for $2.91 billion http://bit.ly/1ln2eXk
#
#
# Strange news day\u2026 Edward Snowden ridiculous Nobel nomination, Andy Murray non-story push notification and now Google selling Motorola.
#
#
# "Disavow & Link Removal: Understanding Google" good read http://feedly.com/e/k3cSQgXL
#
#
# Motorola depreciating faster than my car... Lenovo to Buy Google\u2019s Motorola Unit for $2.91 Billion http://www.bloomberg.com/news/2014-01-29/lenovo-said-near-deal-to-buy-google-handset-unit-for-about-3b.html \u2026
#
#
# Why Google just sold Motorola to Lenovo for $3 billion http://bit.ly/1ibNKF8
#
#
# Even the mighty $goog can't do what $aapl can do in the smartphone market. Sells for a loss.haha $aapl now king of smartphones for awhile
#
#
# Google Autocomplete Explains the Winter Olympics: The Summer Olympics have a pretty straightforward lineup. Ru... http://bit.ly/1cwfoeR
#
#
# Google-less Android Smartphone Segment Growing http://bit.ly/Lq8OMw
#
#
# Google Autocomplete Explains the Winter Olympics http://dlvr.it/4pg62M
#
#
# Google Autocomplete Explains the Winter Olympics http://dlvr.it/4pg5zw
#
#
# Google Autocomplete Explains the Winter Olympics http://dlvr.it/4pg605
#
#
# If there was any doubt about Google's desire to become the next Microsoft of the 80s and the 90s, those doubts should vanish today #Motorola
#
#
# The Mystery of Sex
# Share on facebook Share on twitter Share on google_plusone_share Share on pinterest_share... http://fb.me/2aroKBuu3
#
#
# Remember Google's acquisition of Motorola handset division? (mid-2012, $12.5B).  Google has sold to Lenovo for $3B.
#
#
# @_FiveeeeOhhhh google

# %%
import requests, json, sys, time, re
from bs4 import BeautifulSoup
from pprint import pprint

counter = 0
max_tweets = 40
rate_delay = 5


def build_url(since, until, query, max_position=None):
    space = '%20OR%20'
    q = space.join(query)
    s = '-'.join(since)
    u = '-'.join(until)
    s = '%20lang%3Aen%20since%3A'+s
    u = '%20until%3A'+u

    start = 'https://twitter.com/i/search/timeline?f=tweets&vertical=default&q='        
    end   = '&src=typd&include_available_features=1&include_entities=1&lang=en'
    if max_position is not None:
        URL   = start+q+s+u+end+max_position
    else:
        URL   = start+q+s+u+end
    
    return URL
    


def execute_search(url):
    """
    Executes a search to Twitter for the given URL
    :param url: URL to search twitter with
    :return: A JSON object with data from Twitter
    """
    print(url)
    response = requests. get(url)  
    data = json. loads(response.text)
    return data

def parse_tweets(items_html):
    """
    Parses Tweets from the given HTML
    :param items_html: The HTML block with tweets
    :return: A JSON list of tweets
    """
    soup = BeautifulSoup(items_html)
    tweets = []
    for li in soup.find_all("li", class_='js-stream-item'):

        # If our li doesn't have a tweet-id, we skip it as it's not going to be a tweet.
        if 'data-item-id' not in li.attrs:
            continue

        tweet = {
            'tweet_id': li['data-item-id'],
            'text': None,
            'user_id': None,
            'user_screen_name': None,
            'user_name': None,
            'created_at': None,
            'retweets': 0,
            'favorites': 0
        }

        # Tweet Text
        text_p = li.find("p", class_="tweet-text")
        if text_p is not None:
            tweet['text'] = text_p.get_text()

        # Tweet User ID, User Screen Name, User Name
        user_details_div = li.find("div", class_="tweet")
        if user_details_div is not None:
            tweet['user_id'] = user_details_div['data-user-id']
            tweet['user_screen_name'] = user_details_div['data-user-id']
            tweet['user_name'] = user_details_div['data-name']

        # Tweet date
        date_span = li.find("span", class_="_timestamp")
        if date_span is not None:
            tweet['created_at'] = float(date_span['data-time-ms'])

        # Tweet Retweets
        retweet_span = li.select("span.ProfileTweet-action--retweet > span.ProfileTweet-actionCount")
        if retweet_span is not None and len(retweet_span) > 0:
            tweet['retweets'] = int(retweet_span[0]['data-tweet-stat-count'])

        # Tweet Favourites
        favorite_span = li.select("span.ProfileTweet-action--favorite > span.ProfileTweet-actionCount")
        if favorite_span is not None and len(retweet_span) > 0:
            tweet['favorites'] = int(favorite_span[0]['data-tweet-stat-count'])

        tweets.append(tweet)
    return tweets

def save_tweets(tweets):
    """
    Just prints out tweets
    :return:
    """
    global counter
    global max_tweets
    for tweet in tweets:
        # Lets add a counter so we only collect a max number of tweets
        counter += 1

        if tweet['created_at'] is not None:
            t = datetime.datetime.fromtimestamp((tweet['created_at']/1000))
            fmt = "%Y-%m-%d %H:%M:%S"
            #print "%i [%s] - %s" % (counter, t.strftime(fmt), tweet['text'])
            print (str(counter) + ' ' + str(tweet['tweet_id']) + ' [' + str(t.strftime(fmt)) + '] - ' + str(tweet['text']))
            
        # When we've reached our max limit, return False so collection stops
        if counter >= max_tweets:
            return False

    return True
    
def search(since, until, query):
    first = True
    global rate_delay
    url = build_url(since, until, query)
    continue_search = True
    min_tweet = None
    response = execute_search(url)
    while response is not None and continue_search and response['items_html'] is not None:
        tweets = parse_tweets(response['items_html'])
        if first:
            first = False
        else:   
            position = response['min_position']
            pprint(position)

        # If we have no tweets, then we can break the loop early
        if len(tweets) == 0:
            break

        # If we haven't set our min tweet yet, set it now
        if min_tweet is None:
            min_tweet = tweets[0]

        continue_search = save_tweets(tweets)

        # Our max tweet is the last tweet in the list
        max_tweet = tweets[-1]
        if min_tweet['tweet_id'] is not max_tweet['tweet_id']:
            max_position = "&max_position=TWEET-%s-%s-BD1UO2FFu9QAAAAAAAAETAAAAAcAAAASAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA&reset_error_state=false" % (max_tweet['tweet_id'], min_tweet['tweet_id'])
            url = build_url(since, until, query, max_position=max_position)
            #Sleep for our rate_delay
            sleep(rate_delay)
            response = execute_search(url)
    
    
query = ['google', '$GOOG']
since = ['2014', '01', '01']
until = ['2014', '01', '02']
search(since, until, query)
# Out:
# https://twitter.com/i/search/timeline?f=tweets&vertical=default&q=google%20OR%20$GOOG%20lang%3Aen%20since%3A2014-01-01%20until%3A2014-01-02&src=typd&include_available_features=1&include_entities=1&lang=en
# 1 418532083196514304 [2014-01-01 23:59:59] - Google planning something big with Boston Dynamics - http://www.pingmagazine.tv/news/google-planning-something-big-boston-dynamics/ … pic.twitter.com/mc4AWsdiUE
# 2 418532075294429184 [2014-01-01 23:59:57] - Google planning something big with Boston Dynamics: Boston Dynamics: Now Belongs to Google… http://goo.gl/fb/1NJTV
# 3 418532066767413248 [2014-01-01 23:59:55] - (Ps sorry these aren't mine,me and google are bffs ;3)
# 4 418532062312689666 [2014-01-01 23:59:54] - If i had to guess, i would guess that the number one search word on Bing is Google.
# 5 418532059863212032 [2014-01-01 23:59:53] - @troythedecoy @chrisprodromou @muswellhillspur @louise_s_page it goes back years mate, google it.
# 6 418532054653865984 [2014-01-01 23:59:52] - Wahhahhaa Rt "@dailyteenwords: When I do homework: Books=NO, Library =NO, Google = YES."
# 7 418532048236605441 [2014-01-01 23:59:50] - How Google Analytics Dashboards Can Make Your Life Easier http://kiss.ly/1ePzZMM
# 8 418532041324789760 [2014-01-01 23:59:49] - #KnowYourAnon I'm a virgin but no one long distance believes that because i can sext like a mother fucker thanks to google
# 9 418532040238063616 [2014-01-01 23:59:49] - Most beneficial Google Plus Groups For Your Marketing Efforts http://nblo.gs/Su7h7
# 10 418532016527650816 [2014-01-01 23:59:43] - @kordinglab Look: "Your profile doesn't include a verified email and won't appear in Google Scholar search"
# 11 418532015257161728 [2014-01-01 23:59:43] - @westhamster2 Google, if l was a lesbian l'd want Dido Armstrong as my dear wife  xxx
# 12 418532008449425408 [2014-01-01 23:59:41] - Anybody up for a google hangout it might be only 45 mins though
# 13 418532004968161280 [2014-01-01 23:59:40] - @Pandarama_ right lemme finish game then im gonna google map cause i dunno these ends
# 14 418532003051761664 [2014-01-01 23:59:40] - Idk i got so bored and i was just searching random things into google and i seriously managed to get onto " what is the meaning of life"
# 15 418531999591448577 [2014-01-01 23:59:39] - Mom: "I should work for google. They have snacks and Lego heads."
# 16 418531998164975616 [2014-01-01 23:59:38] - Most beneficial Google Plus Groups For Your Marketing Efforts http://fb.me/1O9TiRbai
# 17 418531992939286528 [2014-01-01 23:59:37] - Google services AGAIN. pic.twitter.com/VQwRNvPUo3
# 18 418531991957798912 [2014-01-01 23:59:37] - Good article: Getting things done with Google Tasks #internet http://www.mattcutts.com/blog/todo-list-tips/ …
# 19 418531978518855681 [2014-01-01 23:59:34] - "Typing song lyrics into Google just to find out the name of the song."
# 20 418531972974391297 [2014-01-01 23:59:32] - Oh nice, buy it then"@Dat_fair_boi: Daabi Tonaton RT @otomatiks: Google search  anaa?"Dat_fair_boi: Have Found Love""
# https://twitter.com/i/search/timeline?f=tweets&vertical=default&q=google%20OR%20$GOOG%20lang%3Aen%20since%3A2014-01-01%20until%3A2014-01-02&src=typd&include_available_features=1&include_entities=1&lang=en&max_position=TWEET-418531972974391297-418532083196514304-BD1UO2FFu9QAAAAAAAAETAAAAAcAAAASAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA&reset_error_state=false
# 'TWEET-418531876353998848-418532083196514304-BD1UO2FFu9QAAAAAAAAETAAAAAcAAAASAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA'
# 21 418531962366603264 [2014-01-01 23:59:30] - #News A New Year's Day dip: Hundreds dive into ocean during polar bear plunge in ... - The Star-L... http://bit.ly/1hgKYk2  Vía @Google
# 22 418531961800388608 [2014-01-01 23:59:30] - #News Former First Lady Barbara Bush Hospitalized - New Philadelphia Times Reporter http://bit.ly/19JZNXD  Vía @Google
# 23 418531960646926336 [2014-01-01 23:59:30] - #News Building explosion in Minneapolis injures 14 people, 6 critically, authorities say - Fox News http://bit.ly/1gn9T2n  Vía @Google
# 24 418531958466293760 [2014-01-01 23:59:29] - Google Glass won't succeed as a consumer product in 2014 due to high expectations, cost, more » http://bit.ly/KjNCaY  #tech
# 25 418531956343996416 [2014-01-01 23:59:29] - With the help of google I have diagnosed myself with insomnia
# 26 418531956151029760 [2014-01-01 23:59:28] - New Event Now On. GET Rank AAA Monsters. App Store: http://bit.ly/AzhyKP  Google Play: http://bit.ly/NtcNTs  #DarkSummoner
# 27 418531951520526336 [2014-01-01 23:59:27] - Talk I'm telling you this is getting big. Last week we had Toni Woods google him. We got a special… http://instagram.com/p/ipUKRkGsyr/
# 28 418531944796663809 [2014-01-01 23:59:26] - Learn HOW to Build a Website in WordPress, That will get Google's Attention - http://eepurl.com/LBx9z
# 29 418531944490889217 [2014-01-01 23:59:26] - A Sensible Health Care System for All Americans - Google Drive http://ow.ly/sc84m
# 30 418531937540931585 [2014-01-01 23:59:24] - @Zadddy_Dirah @MoonTooCool we saw you on google you was looking HIT
# 31 418531937104302080 [2014-01-01 23:59:24] - "Hey google image SHUT THE F*CK UP." -dad
# 32 418531925989797888 [2014-01-01 23:59:21] - @jammmiexo google what first period is tomorrow
# 33 418531911368069120 [2014-01-01 23:59:18] - WHY IS GOOGLE CHROME SO FUCKING SHIT
# 34 418531903885828096 [2014-01-01 23:59:16] - You don't know something? Google it. You don't know someone? Facebook it. You don't find something? MOM!
# 35 418531899179798529 [2014-01-01 23:59:15] - Bump bumped-off as Google quickly shuts down file-sharing acquisition - http://www.appy-geek.com/Web/ArticleWeb.aspx?regionid=1&articleid=17248051 …
# 36 418531896071815168 [2014-01-01 23:59:14] - Blogging Income & Expenses Spreadsheet - Free Google Drive download http://pinterest.com/pin/3799980909480888/ …
# 37 418531885652795392 [2014-01-01 23:59:12] - How Google and Apple are turning your car into a giant smartphone http://www.nbcnews.com/technology/how-google-apple-are-turning-your-car-giant-smartphone-2D11820932 …
# 38 418531881915645952 [2014-01-01 23:59:11] - Don't mess with #google. RT @zaibatsu: One chart shows Google's awesome power to kill your website's traffic http://zite.to/1cmCK1v
# 39 418531879520718848 [2014-01-01 23:59:10] - @Kirsty_Henshaw just done a quick google it could well help. Tai chi and Chi Gung builds strength but are lots gentler! Acupuncture too
# 40 418531876353998848 [2014-01-01 23:59:09] - Google-owned Bump and Flock announce January 31 http://www.regrit.com/google-owned-bump-and-flock-announce-january-31st-shutdown-app-store-removal/ … #App #appstore #Apps #bump #CEO #data #DavidLieb #Flock #good #g
# https://twitter.com/i/search/timeline?f=tweets&vertical=default&q=google%20OR%20$GOOG%20lang%3Aen%20since%3A2014-01-01%20until%3A2014-01-02&src=typd&include_available_features=1&include_entities=1&lang=en&max_position=TWEET-418531876353998848-418532083196514304-BD1UO2FFu9QAAAAAAAAETAAAAAcAAAASAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA&reset_error_state=false
